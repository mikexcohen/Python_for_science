# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Data curve fitting
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt

import lmfit.models as models
from lmfit import Model

# %% [markdown]
# # Fit a Gaussian

# %%
# Gaussian model
gausmodel = models.

# Gaussian parameters
x = 
a =    # amplitude
c =   # center
s =  # standard deviation (width)

# generate some data using the model and add noise
data = 

# and plot
plt.plot(x,data,'.')
plt.show()

# %%
# fit the model to the data

gausfit = 
result = 

# R2 fit
r2 = 

# print model statistics

# %%
# some visualization
plt.legend()
plt.title()
plt.show()

print('\n\n\n\n')

# using the built-in method on the model-fit class

# %% [markdown]
# # Model an exponential decay

# %%
# x variable exponential decay
x = 

# generate some data (not using the lmfit model)
data = 

# and plot
plt.plot(x,data,'.')
plt.show()

# %%
# fit model and show the results
expdecay_fit = 
result =

# %% [markdown]
# # Use a user-defined function (sigmoid)

# %%
# create the data
x = np.linspace(-2,2,301)
data = # create data as a sigmoid plus noise

plt.plot(x,data);

# %%
# let's make our own function for the sigmoid

def sigmoid(x...):
  


# then fit that model
sigmodel = 
result = 

# R2 fit
r2 = 

# print model statistics

# %%
# some visualization as before

# %% [markdown]
# # Conjunctive model fitting

# %%
# create data
x = 
data = 

plt.plot(x,data)
plt.show()

# %%
# define the model
conj_model = 

# compute the model
gauslin = 

# R2 fit
r2 = 

# print model statistics

# %%
# using built-in method with extra options
gauslin.plot_fit();

# %% [markdown]
# # Multivariate model fitting

# %%
# create the circle data
n = 100

th = 
r =  # radius

# x and y values from cos and sine (and add a bit of noise)
x = 
y = 

plt.plot(x,y,'k.')
plt.gca().set_aspect(1./plt.gca().get_data_ratio())
plt.axis('off')
plt.show()

# %%
# the function to fit
def circlefit(th,r=1):

# %%
# define the model
circ_model = 
result = 

# visualize

# %% [markdown]
# # Bonus: The eye of Sauron!
