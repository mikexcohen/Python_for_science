# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Time series filtering
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt
from scipy import signal
import scipy.fftpack

# %% [markdown]
# # Generate a signal with random noise

# %%
# create 10 seconds of time using a sampling rate of 1000 Hz
srate = 
time  = 
npnts = 

# create random data from N(5,1)
data = 

# add 50 Hz "line noise"
linenoise = 


# spectral stuff
hz = np.linspace(0,srate/2,int(npnts/2)+1)

# %%
## create a function that will plot the time and frequency-domain plots

def plotSignal(data):
  fig,ax = plt.subplots(1,2,figsize=(20,6))
  
  # FFT of the data
  dataX = 
  

plotSignal(data)

# %% [markdown]
# # Notch out line noise

# %%
f0 = 50  # Frequency to be removed from signal (Hz)
Q = 50  # Quality factor
# Design notch filter
b,a = signal.iirnotch

# evaluate the filter kernel
freq,h = signal.freqz
plt.plot(freq,abs(h)**2)
plt.title("Frequency Response")
plt.ylabel("Amplitude (gain)")
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 100])
plt.show()

# %%
# notch-filter the signal
notched = signal.filtfilt

# call the plotting functions for the raw data and notched data
plotSignal(data)
plotSignal(notched)

# %%
# show both plots on top of each other (not using the function plotSignal)

# %% [markdown]
# # High-pass FIR filter

# %%
# create the filter kernel
lowedge = 20 # Hz
fkern = signal.firwin # mind the input settings!


# evaluate the filter kernel
freq,h = signal.freqz
plt.plot(freq,abs(h)**2)
plt.title("Frequency Response")
plt.ylabel("Amplitude (gain)")
plt.xlabel('Frequency (Hz)')
plt.xlim([0, 100])
plt.show()

# %%
# apply the filter to the signal (the notched filtered, not the original signal)
highpass = signal.filtfilt

# same overlapping plotting as in the previous video.

# %% [markdown]
# # Low-pass IIR filter

# %%
# low cut-off for filter
lowcutoff = 30

# create filter coefficients using butterworth filter
b,a = signal.

# evaluate the filter kernel
freq,h = signal.freqz
plt.plot
plt.title("Frequency Response")
plt.ylabel("Amplitude (gain)")
plt.xlabel('Frequency (Hz)')
plt.xlim([0,100])
plt.show()

# %%
# apply the butterworth filter to the signal.
# use the filtered signal from the previous video, not the raw signal.
bandpass = signal.filtfilt

# same plot as above

# %% [markdown]
# # Bonus: make a desert landscape
