# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Descriptive statistics without numpy
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import modules
import numpy as np # for generating data

# %% [markdown]
# # Mean and median

# %%
# create a dataset
N = 
data =

# %%
# compute the mean and compare to numpy's mean

mymean = 
npmean = 

print(mymean)
print(npmean)

# %%
# compute the median


# numpy's median
npmedian = 

print(mymedian)
print(npmedian)

# %% [markdown]
# # Frequencies table

# %%
# new dataset of integers
data =

# %%
# compute the unique values and their counts


print(uniquevals)
print(valcounts)

# %%
# now make the table (as dictionary)
table = {}

# %% [markdown]
# # Mode

# %%
# maximum count
maxcount = 0

# loop through table items and find largest count

print('Mode = %s (appears %s times)'%(mode,maxcount))

# %%
# compute the median using scipy's stats module

# %% [markdown]
# # Standard deviation

# %%
# a new random dataset (poisson noise)

N = 51
data = 

meanval = # remove numpy type!


print(std)
print(np.std(data)) # numpy's std function

# %% [markdown]
# # Bonus: Create a csv report

# %%
# create functions for each descriptive statistic

# %%
# create the dataset of random integers
data = 

statlabels = [ 'mean','median','mode','std' ]

# write to a text file called 'stats.csv'

# %%
# download that file to disk
from google.colab import files
