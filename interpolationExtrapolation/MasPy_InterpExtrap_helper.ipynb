# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Interpolation and extrapolation
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules

# %% [markdown]
# # Down/upsample a time series

# %%
# generate a smooth time series

N = 1000 # time points
k = # k-point mean-smoothing kernel
timevec = np.arange(N)/N

# create smoothed time series
tsO = 
ts  = np.convolve()

# plot them
plt.plot(timevec,tsO)
plt.plot(timevec,ts)
plt.xlim(timevec[[0,-1]])
plt.xlabel
plt.show()

# %%
# downsample to 1/2 the original rate

ts_ds = signal.resample # ds = downsampled
timevec_ds = 

plt.plot(timevec,ts,'r')
plt.plot(timevec_ds,ts_ds,'b.')
# zoom in to have a closer look at the spacing
plt.show()

# %%
# upsample to 3x the original rate

ts_us = 
timevec_us = 

# plot
# zoom in!
plt.show()

# %% [markdown]
# # 1D interpolation

# %%
# Create a 6-point signal and visualize
sig = np.array([  ])

# %%
# interpolate using numpy

interp_factor = 

orig_points = np.arange(len(sig))
interp_points = 

interp_sig = np.interp

plt.plot(interp_points,interp_sig,'rs-')
plt.plot(orig_points,sig,'o',markersize=14)
plt.show()

# %%
# again, using scipy

interp_factor = 2

interp_funL = interpolate. # linear interpolation
interp_funC = interpolate. # cubic interpolation

# plotting
plt.legend()
plt.show()

# %% [markdown]
# # 1D extrapolation

# %%
# extrapolation (scipy)

interp_factor = 2

# specify new x-axis points
interp_points = np.linspace(,,)

interp_funL = interpolate. # linear
interp_funC = interpolate. # cubic
interp_sigL = interp_funL(
interp_sigC = interp_funC(

plt.plot(interp_points,interp_sigL,'rs-',label='linear')
plt.plot(interp_points,interp_sigC,'mp-',label='cubic')
plt.plot(orig_points,sig,'o',markersize=14,label='original')
plt.legend()
plt.ylim([-3,13])
plt.show()

# %% [markdown]
# # Resampling revisited

# %%
# use interpolation to fix the upsampling


plt.plot(timevec,ts,'rs',label='Original')
plt.plot(timevec_us,ts_us+2,'b.',label='Upsampled')
plt.plot(timevec_usRegular,ts_usRegular+4,'k.',label='Upsampled/interpolated')
plt.xlim([.6,.605])
plt.legend()
plt.show()

# %% [markdown]
# # Fix corrupted image with interpolation

# %%
# create 2D function
x = np.linspace(,,60)
X,Y = np.meshgrid
Zgood = # Zgood is the original matrix without corruption

# visualize
plt.imshow
plt.show()

# %%
# select pixels to corrupt

pct_bad_pixels = 

# total number of elements in Zgood
num_elements = 

# pick random pixel indices
badpix_idx =

# %%
# destroy those pixels
Z = # make a copy of Zgood

# set bad pixels in Z to nan


# visualize
plt.imshow(Z,extent=[x[0],x[-1],x[0],x[-1]],origin='lower')
plt.show()

# %%
# find good and bad indices
badidx_i,badidx_j = 
gooidx_i,gooidx_j = 

# interpolate using griddata
Znewpix = interpolate.griddata

# make a copy of Z and replace bad pixels with good ones
Zinterp = 
Zinterp[badidx_i,badidx_j] =

# %%
# visualize everything
fig,ax = plt.subplots(1,3,figsize=(14,7))

# original image
ax[0].imshow
ax[0].set_title('Original')

# corrupted image
ax[1].imshow
ax[1].set_title('Corrupted')

# corrected image
ax[2].imshow
ax[2].set_title('Interpolated')

plt.show()

# %%
# show the difference map to evaluate the interpolation quality
diffmap = 

plt.imshow(diffmap,vmin=,vmax=)
plt.show()

# %% [markdown]
# # Bonus:
