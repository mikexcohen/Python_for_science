# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Local minimum via gradient descent
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt
import sympy as sym
import copy

# %% [markdown]
# # The function and its derivative

# %%
# function


# derivative function

# %%
# plot the function and its derivative

# define a range for x
x = 

# plotting
plt.plot()
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend
plt.show()

# %%
# (optional) compute the minimum by hand via calculus

# %% [markdown]
# # Gradient descent

# %%
# random starting point
localmin = 

# learning parameters
learning_rate
training_epochs

# run through training

# %%
# plot the function, its derivative, and the obtained local minimum

# %%
# repeat the above but store the local min and gradient on each iteration

# %%
# plot the gradient over iterations

# %% [markdown]
# # Repeat in 2D

# %%
# MATLAB's special 'peaks' formula

def peaks(x,y):
  # expand to a 2D mesh
  x,y = np.meshgrid(x,y)

  z = 3*(1-x)**2 * np.exp(-(x**2) - (y+1)**2) \
      - 10*(x/5 - x**3 - y**5) * np.exp(-x**2-y**2) \
      - 1/3*np.exp(-(x+1)**2 - y**2)
  return z

# %%
# create the landscape
x = 
y = 

Z = peaks

# let's have a look!
plt.imshow
plt.show()

# %%
# create derivative functions using sympy

sx,sy = sym.symbols('sx,sy')

sZ = 3*(1-sx)**2 * sym.exp(-(sx**2) - (sy+1)**2) \
      - 10*(sx/5 - sx**3 - sy**5) * sym.exp(-sx**2-sy**2) \
      - 1/3*sym.exp(-(sx+1)**2 - sy**2)


# create functions from the sympy-computed derivatives
df_x = sym.lambdify( (sx,sy),sym.diff(sZ,sx),'sympy' )
df_y = # tip: modify the previous line

df_x(1,1).evalf()

# %%
# random starting point (uniform between -2 and +2)
localmin = 
startpnt = # make a copy of localmin

# learning parameters
learning_rate = 
training_epochs =

# run through training
trajectory = # for storing the trajectory on each iteration of learning
for i in range(training_epochs):
  grad = 
  localmin = 
  trajectory[i,:] =

# %%
# let's have a look!

# plot the peaks image
plt.imshow(Z
           
# plot the starting point and final local minimum
plt.plot
plt.plot

# and the entire trajectory
plt.plot(,'r')
plt.legend(['rnd start','local min'])
plt.colorbar()
plt.show()

# %% [markdown]
# # Bonus: Visualize in 3D

# %%
# setup an axis for 3D rendering
fig = 
ax  = plt.axes(projection='3d')

# need a meshgrid (normally computed inside the peaks function)
xx,yy = 

# draw the surface (tip: make it partly transparent)
surf = ax.plot_surface

# add the starting point and local minimum
ax.scatter(
ax.scatter(

ax.view_init(40,20)
ax.axis('off')
plt.show()
