# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: The colorful rainbow of noise
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt
import scipy.fftpack as fftpack
import scipy.signal as signal

# %% [markdown]
# # White and brown noise

# %%
# number of data points
npnts = int( 1e5 )

# create noise signals
whitenoise = 
brownnoise = 

# plot both on the same graph
plt.show()

# %%
# now plot both on a yy-plot (same axis but different scales for each noise color)
fig,ax = plt.subplots(1)

plt.show()

# %%
# compute power spectra
whitenoiseX = 
brownnoiseX = 

# vector of frequencies (normalized to Nyquist)
frex = np.linspace(0,1,int(npnts/2))

# show the spectra
plt.plot(frex,brownnoiseX[:len(frex)]


plt.legend(['Brown','White'])
plt.ylim
plt.ylabel('Amplitude (a.u.)')
plt.xlabel('Frequency (fraction of Nyquist)')
plt.show()

# %% [markdown]
# # Pink and blue noise

# %%
# pink noise

# initialize a Fourier spectrum
FourierSpect = 

# create the amplitude and phase coefficients
fc_amp = 
fc_phs = 

# compute the spectrum and invert to the time domain
FourierSpect[:int(npnts/2)] = 
pinknoise =

# %%
# compute the power spectrum
pinknoiseX = 

# plot the time domain signal on the left, and spectrum on the right
fig,ax = plt.subplots(1,2,figsize=(12,4))
ax[0].set_title('Time domain')

ax[1].set_title('Frequency domain')
plt.show()

# %%
# blue noise (hint: paste code from creating pink noise)


bluenoise = np.real(fftpack.ifft(FourierSpect))

# %%
# same plots as for pink noise

# %% [markdown]
# # The colorful spectrum of the rainbow

# %%
# recreate and set amplitude params to match

# %%
# create noise-creation functions here

# %%
# plot them all in the same graph

plt.ylabel('Amplitude (a.u.)')
plt.xlabel('Frequency (fraction of Nyquist)')
plt.title('Frequency domain')
plt.show()

# %% [markdown]
# # Bonus: How do they sound?

# %%
print('White noise')
Audio(whitenoise,rate=44100)
