# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Awesome mathy stuff
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Pascal's triangle

# %%
# create a function for nChooseK
# hint: math module?

def nChooseK(n,k):
  num = 
  den = 
  return num/den

# %%
# call your function in a double-loop to create the matrix

n = 5

# initialize square matrix
PT = 

for i in range(n):
  for j in range
    PT[,] = nChooseK

plt.imshow(PT)
plt.show()
print(PT)

# %%
# print out a triangle using the right number of spaces

for i in range(n):
  # tip: create a convenience variable
  tmp = PT[i,:]
  # tip: figure out how many spaces to print before the numbers in this row
  print(' ')

# %% [markdown]
# # Euler's identity

# %%
# define magnitude and phase

m = 
p = 

# euler notation
euler = 

# compute rectangular notation
rect = 

# show that they are the same
print(euler)
print(rect)

# %%
# show the results in a graph

# extract radius and angle from euler
radius = 
theta  = 

# plot using polar
plt.polar

# now overlay with a rectangular plot
plt.plot(np.real(euler),np.imag(euler),'ro',label='Euler')
plt.show()

# %%
### IMPORTANT: The above plot is mismatched. The polar and cartesian plots are not aligned.
# try again by adding separate axes that you can independently control.

fig = plt.figure()

m = 1.3
p = np.pi*.65

euler  = m * np.exp(1j*p)
radius = 
theta  = 

# setup figure
ax_cart = fig.add_axes...
ax_polr = fig.add_axes...,polar=True,frameon=False)

# draw plots
ax_polr.plot(,'k+',markersize=15)
ax_cart.plot(,'ro',markersize=15)


### now adjust the axes so they match

# get maximal radius of polar plot
r = 
print(r)

# and then adjust the x and y axis limits of the cartesian axis
ax_cart.set_xlim
ax_cart.set_ylim
ax_cart.set_aspect
ax_cart.set_xlabel('Real')
ax_cart.set_ylabel('Imag')

plt.show()

# %% [markdown]
# # Fully parameterized Gaussian

# %%
# define x range to evaluate the function
x = 

# create a function to create the function
def makeGauss(amp,s,offset=0):
  return something awesome!

# %%
# make a few random gaussians just to explore the parameter space a bit.

plt.xlabel('x')
plt.ylabel('g(x)')
plt.show()

# %%
# a Gaussian image with varied amplitudes
amps = np.linspace

# initialize the output matrix
G = np.zeros

# populate that matrix with Gaussians
for a in range(.1):
  G[a,:] = 

plt.imshow(G,) # make sure the axis ticks are correct
plt.xlabel('X (time?)')
plt.ylabel('Amplitude')
plt.title('Varying a')
plt.show()

# %%
# repeat the previous cell but varying the offsets

# %%
# repeat the previous cell but varying the widths (parameter sigma)

# %% [markdown]
# # .
# # .
# # .

# %% [markdown]
# # Time dilation in special relativity

# %%
# speed of light (mps)
c = 299792458

# create a lambda function for the formula in the slides
timedil =

# %%
# some speeds...
kph = np.zeros(6)

kph[0] = 100     # car on highway
kph[1] = 200     # crazy people on the German autobahn
kph[2] = 900     # airplane
kph[3] = 11300   # satellite
kph[4] = 107991  # Earth around the sun
kph[5] = 828000  # solar system around galaxy

labels = ['car','autobahn','plane','satellite','Earth','Solar system']

# %%
# compute time dilation for the different speeds

td = np.zeros(len(kph))

for i in range(len(kph)):

    # convert to m/s
    v = 

    # compute time dilation
    td[i] = 

print(td)

# %%
# show them all in a bar plot with angled x-axis labels.

plt.show()

# %% [markdown]
# # Complex eigenvalues

# %%
# matrix size
n = 15

# setup figure
fig,ax = plt.subplots(1,2,figsize=(12,5))

# loop over 100 iterations
mags = []
for i in range(100):
  # get eigenvalues of random matrices
  L = 
  # store the magnitudes
  
  # and plot on a complex plane
  



ax[0].set_xlabel('real')
ax[0].set_ylabel('imag')
ax[0].set_title('Eigenvalues in the complex plane')



# now plot the eigenvalue magnitudes, sorted descending
ax[1].plot(mags,'o')
ax[1].set_title('Sorted eigenvalue magnitudes')
ax[1].set_xlabel('Matrix/eigenvalue number')
plt.show()

# %% [markdown]
# # Bonus: I heart math

# %%
# awww, how cute!
