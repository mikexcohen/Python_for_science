# %% [markdown]
# # COURSE: Master Python for scientific programming by solving projects
# ## PROJECT: Spectral analysis
# #### TEACHER: Mike X Cohen, sincxpress.com
# ##### COURSE URL: udemy.com/course/maspy_x/?couponCode=202201

# %%
# import all necessary modules
import numpy as np
import matplotlib.pyplot as plt
from scipy.signal import welch

# %% [markdown]
# # Simulate an AR process

# %%
# temporal weighting vector
w = 
k = len(w)

N = 200

# define each new datapoint as a weighted combination of previous data points


# add sine wave


# plot the signal
plt.plot(x)
plt.xlabel('X axis')
plt.ylabel('Value')
plt.title('AR(%g) process'
plt.show()

# %% [markdown]
# # Code the Fourier transform

# %%
# normalized time vector for the complex sine waves
t = np.arange(0,N)/N

# initialize complex-valued Fourier coefficients
fc = 

for f in range(N):
  # create complex sine wave
  csw = 

  # dot product with signal
  fc[f] =

# %%
# check against numpy's fft function
fc2 =

# %%
# normalized frequencies vector
hz = 

# and plot
plt.plot(hz,np.abs(),label='Manual FT')
plt.plot(hz,np.abs(),'ro',label='FFT')
plt.xlabel('Frequency (fraction of Nyquist)')
plt.ylabel('Amplitude (a.u.)')
plt.legend()
plt.show()

# %% [markdown]
# # Zero-padding the FFT

# %%
# new signal with N=21

# generate an AR2 process like above

# %%
# for-loop to run FFT and plot power spectrum

for i in range(3):
  nfft = 
  
  # spectrum of signal (use fft function; not the hand-coded loop!)
  xX = 
  
  # normalized frequencies vector
  hz = 
  
  # and plot
  plt.plot(np.abs(xX[:len(hz)])**2,'.-',label='%s-point FT'%nfft)
  
plt.xlabel('Frequency (fraction of Nyquist)')
plt.ylabel('Power (a.u.)')
plt.legend()
plt.show()

# %% [markdown]
# # Welch's method

# %%
# signal with phase reversal

N = 2000
t = np.linspace(0,4*np.pi,N)
signal1 = 
signal2 = 

plt.plot(signal1)
plt.plot(signal2)
plt.show()

# %%
# "static" FFT
staticX1 = np.fft.fft(signal1)
staticX2 = np.fft.fft(signal2)
staticHz = np.linspace(0,1,int(len(signal1)/2+1))

# welch's method 



# And plot
fig,ax = plt.subplots(1,2,figsize=(13,4))

ax[0].plot(staticHz,np.abs(staticX1[:len(staticHz)]),'-o',label='Signal 1')
ax[0].plot(staticHz,np.abs(staticX2[:len(staticHz)]),'-o',label='Signal 2')
ax[0].legend()
ax[0].set_xlim([0,.01])
ax[0].set_title('Static spectrum via FFT')

ax[1].plot(dynamicHz,np.abs(dynamicX1[:len(dynamicHz)]),'-o',label='Signal 1')
ax[1].plot(dynamicHz,np.abs(dynamicX2[:len(dynamicHz)]),'-o',label='Signal 2')
ax[1].legend()
ax[1].set_xlim([0,.01])
ax[1].set_title('Dynamic spectrum via Welch')

plt.show()

# %% [markdown]
# # Bonus: Export figures as pdf

# %%
# exact repeat of previous figure

fig,ax = plt.subplots(1,2,figsize=(13,4))

ax[0].plot(staticHz,np.abs(staticX1[:len(staticHz)]),'-o',label='Signal 1')
ax[0].plot(staticHz,np.abs(staticX2[:len(staticHz)]),'-o',label='Signal 2')
ax[0].legend()
ax[0].set_xlim([0,.01])
ax[0].set_title('Static spectrum via FFT')

ax[1].plot(dynamicHz,np.abs(dynamicX1[:len(dynamicHz)]),'-o',label='Signal 1')
ax[1].plot(dynamicHz,np.abs(dynamicX2[:len(dynamicHz)]),'-o',label='Signal 2')
ax[1].legend()
ax[1].set_xlim([0,.01])
ax[1].set_title('Dynamic spectrum via Welch')


### export as pdf and png

# %%
# download to disk
